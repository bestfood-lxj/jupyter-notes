# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()
Drawing_colored_circle = plt.Circle((8,8), 6,fill=False)

axes.set_aspect(1)

axes.add_artist(Drawing_colored_circle)
ax = plt.gca()
ax.set_xlim([1,15])
ax.set_ylim([1,15])
plt.plot([8],[8], marker='o', color='black')
plt.show()

# %%
import matplotlib.pyplot as plt
figure, axes = plt.subplots()
radical = 3**(0.5)
axes.plot([1,2,1,-1,-2,-2,-1,1,],[0,radical2+2*radical,2+2*radical,2+radical,radical,0,0])
#axes.plot([1,0,-1,1,2,1,-1,-2,-1],[0,radical,0,0,radical,2*radical,2*radical,radical,0])
ax = plt.gca()
axes.set_aspect('equal', adjustable='box')
plt.show()
